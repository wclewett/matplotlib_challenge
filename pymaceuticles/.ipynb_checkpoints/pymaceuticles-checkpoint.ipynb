# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import scipy.stats as st
from scipy.stats import linregress

plt.style.use(['classic'])

# Study data files
mouse_metadata_path = "data/Mouse_metadata.csv"
study_results_path = "data/Study_results.csv"

# Read the mouse data and the study results
mouse_metadata = pd.read_csv(mouse_metadata_path)
study_results = pd.read_csv(study_results_path)

# Combine the data into a single dataset
study_meta = pd.merge(study_results, mouse_metadata, how = 'left', on = 'Mouse ID')
# Display the data table for preview
study_meta
# Out:
#      Mouse ID  Timepoint  Tumor Volume (mm3)  Metastatic Sites Drug Regimen  \
# 0        b128          0           45.000000                 0    Capomulin
# 1        f932          0           45.000000                 0     Ketapril
# 2        g107          0           45.000000                 0     Ketapril
# 3        a457          0           45.000000                 0     Ketapril
# 4        c819          0           45.000000                 0     Ketapril
# ...       ...        ...                 ...               ...          ...
# 1888     r944         45           41.581521                 2    Capomulin
# 1889     u364         45           31.023923                 3    Capomulin
# 1890     p438         45           61.433892                 1     Ceftamin
# 1891     x773         45           58.634971                 4      Placebo
# 1892     b879         45           72.555239                 2     Stelasyn
#
#          Sex  Age_months  Weight (g)
# ...

# %%
# Checking the number of mice.
mice_unique = list(study_meta['Mouse ID'].unique())
print(f'{len(mice_unique)} mice were tested in the study.')
# Out:
# 249 mice were tested in the study.

# %%
# Getting the duplicate mice by ID number that shows up for Mouse ID and Timepoint. 
study_meta_time = study_meta.groupby(by=['Mouse ID'])
mice_counts = pd.DataFrame(study_meta_time['Timepoint'].value_counts())
mice_dup_bool = mice_counts['Timepoint'] > 1
mice_counts[mice_dup_bool]
# Out:
#                     Timepoint
# Mouse ID Timepoint
# g989     0                  2
#          5                  2
#          10                 2
#          15                 2
#          20                 2

# %%
# Optional: Get all the data for the duplicate mouse ID. 
meta_mice_dup_bool = study_meta['Mouse ID'] == mice_counts[mice_dup_bool].transpose().keys()[0][0]
study_meta[meta_mice_dup_bool]
# Out:
#      Mouse ID  Timepoint  Tumor Volume (mm3)  Metastatic Sites Drug Regimen  \
# 107      g989          0           45.000000                 0     Propriva
# 137      g989          0           45.000000                 0     Propriva
# 329      g989          5           48.786801                 0     Propriva
# 360      g989          5           47.570392                 0     Propriva
# 620      g989         10           51.745156                 0     Propriva
# 681      g989         10           49.880528                 0     Propriva
# 815      g989         15           51.325852                 1     Propriva
# 869      g989         15           53.442020                 0     Propriva
# 950      g989         20           55.326122                 1     Propriva
# 1111     g989         20           54.657650                 1     Propriva
# 1195     g989         25           56.045564                 1     Propriva
# ...

# %%
# Create a clean DataFrame by dropping the duplicate mouse by its ID.
meta_mice_singulars = study_meta['Mouse ID'] != mice_counts[mice_dup_bool].transpose().keys()[0][0]
study_meta = study_meta[meta_mice_singulars]
study_meta
# Out:
#      Mouse ID  Timepoint  Tumor Volume (mm3)  Metastatic Sites Drug Regimen  \
# 0        b128          0           45.000000                 0    Capomulin
# 1        f932          0           45.000000                 0     Ketapril
# 2        g107          0           45.000000                 0     Ketapril
# 3        a457          0           45.000000                 0     Ketapril
# 4        c819          0           45.000000                 0     Ketapril
# ...       ...        ...                 ...               ...          ...
# 1888     r944         45           41.581521                 2    Capomulin
# 1889     u364         45           31.023923                 3    Capomulin
# 1890     p438         45           61.433892                 1     Ceftamin
# 1891     x773         45           58.634971                 4      Placebo
# 1892     b879         45           72.555239                 2     Stelasyn
#
#          Sex  Age_months  Weight (g)
# ...

# %%
# Checking the number of mice in the clean DataFrame.
mice_unique = list(study_meta['Mouse ID'].unique())
print(f'{len(mice_unique)} mice exist the clean dataset.')
# Out:
# 248 mice exist the clean dataset.

# %%
# Generate a summary statistics table of mean, median, variance, standard deviation, and SEM of the tumor volume for each regiment.

# This method is the most straighforward, creating multiple series and putting them all together at the end.

# %%
# Generate a summary statistics table of mean, median, variance, standard deviation, and SEM of the tumor volume for each regimen
regiment_group = study_meta.groupby(by=['Drug Regimen'])
summary_stats = pd.DataFrame(regiment_group['Tumor Volume (mm3)'].count())
summary_stats = summary_stats.rename(columns = {'Tumor Volume (mm3)': 'Count'})
summary_stats['Mean'] = pd.DataFrame(regiment_group['Tumor Volume (mm3)'].mean())
summary_stats['Median'] = regiment_group['Tumor Volume (mm3)'].median()
summary_stats['Standard Deviation'] = regiment_group['Tumor Volume (mm3)'].std()
summary_stats['Variance'] = regiment_group['Tumor Volume (mm3)'].std() ** 2
summary_stats['Standard Error'] = summary_stats['Standard Deviation'] / (summary_stats['Count'] ** 1/2)
summary_stats
# This method produces everything in a single groupby function
# Out:
#               Count       Mean     Median  Standard Deviation   Variance  \
# Drug Regimen
# Capomulin       230  40.675741  41.557809            4.994774  24.947764
# Ceftamin        178  52.591172  51.776157            6.268188  39.290177
# Infubinol       178  52.884795  51.820584            6.567243  43.128684
# Ketapril        188  55.235638  53.698743            8.279709  68.553577
# Naftisol        186  54.331565  52.509285            8.134708  66.173479
# Placebo         181  54.033581  52.288934            7.821003  61.168083
# Propriva        148  52.320930  50.446266            6.622085  43.852013
# Ramicane        228  40.216745  40.673236            4.846308  23.486704
# Stelasyn        181  54.233149  52.431737            7.710419  59.450562
# Zoniferol       182  53.236507  51.818479            6.966589  48.533355
#
#               Standard Error
# Drug Regimen
# Capomulin           0.043433
# Ceftamin            0.070429
# Infubinol           0.073789
# ...

# %%
# Generate a bar plot showing the total number of mice for each treatment throughout the course of the study using pandas. 
summary_stats['Count'].plot.bar()

# %%
# Generate a bar plot showing the total number of mice for each treatment throughout the course of the study using pyplot.
# Run Cell Twice to Resize
x_axis = np.arange(len(summary_stats['Count']))
tick_locations = [value for value in x_axis]
plt.xticks(tick_locations, study_meta['Drug Regimen'].unique())
plt.title("Mice Used by Drug Regimen")
plt.xlabel("Drug Regimen")
plt.ylabel("Mice Count")

plt.rcParams["figure.figsize"] = [16,8]

plt.bar(x_axis, summary_stats['Count'], width = 0.5, color='b', alpha=0.5, align="center")
# Out:
# <BarContainer object of 10 artists>

# %%
# Generate a pie plot showing the distribution of female versus male mice using pandas
mouse_metadata['Sex'].value_counts().plot.pie()

# %%
# Generate a pie plot showing the distribution of female versus male mice using pyplot
# Labels for the sections of our pie chart
labels = ['Female', 'Male']

# The values of each section of the pie chart
sizes = mouse_metadata['Sex'].value_counts()

# The colors of each section of the pie chart
colors = ["red", "lightskyblue"]

# Tells matplotlib to seperate the "Humans" section from the others
explode = (0.1, 0)
plt.pie(sizes, explode=explode, labels=labels, colors=colors,
        autopct="%1.1f%%", shadow=True, startangle=140)
plt.title('Gender Makeup across All Studies')
# Out:
# Text(0.5, 1.0, 'Gender Makeup across All Studies')

# %%
# Calculate the final tumor volume of each mouse across four of the treatment regimens:  
# Capomulin, Ramicane, Infubinol, and Ceftamin

# Start by getting the last (greatest) timepoint for each mouse
best_timepoint = pd.DataFrame(study_meta.groupby(by='Mouse ID')['Timepoint'].max())
best_timepoint = best_timepoint.rename(columns = {'Timepoint': 'Timepoint'})
best_timepoint
# Merge this group df with the original dataframe to get the tumor volume at the last timepoint
timepoint_slice = pd.merge(best_timepoint, study_results, how = 'left', on = 'Mouse ID')
best_time_slice = timepoint_slice[timepoint_slice['Timepoint_x'] == timepoint_slice['Timepoint_y']]
best_time_df = pd.merge(best_time_slice, mouse_metadata, on = 'Mouse ID', how = 'left')
# Clean dataset again since duplicate mouse is in the new best timepoint dataset
meta_mice_singulars = best_time_df['Mouse ID'] != mice_counts[mice_dup_bool].transpose().keys()[0][0]
best_time_df = best_time_df[meta_mice_singulars]
best_time_df = best_time_df.drop(['Timepoint_x'], axis = 1)
best_time_df = best_time_df.rename(columns = {'Timepoint_y': 'Best Timepoint'})
best_time_df
# Out:
#     Mouse ID  Best Timepoint  Tumor Volume (mm3)  Metastatic Sites  \
# 0       a203              45           67.973419                 2
# 1       a251              45           65.525743                 1
# 2       a262              45           70.717621                 4
# 3       a275              45           62.999356                 3
# 4       a366              30           63.440686                 1
# ..       ...             ...                 ...               ...
# 243     z435              10           48.710661                 0
# 244     z578              45           30.638696                 0
# 245     z581              45           62.754451                 3
# 246     z795              45           65.741070                 3
# 247     z969              45           73.867845                 4
#
#     Drug Regimen     Sex  Age_months  Weight (g)
# 0      Infubinol  Female          20          23
# 1      Infubinol  Female          21          25
# ...

# %%
# Put treatments into a list for for loop (and later for plot labels)
interested_trials = ['Capomulin', 'Ramicane', 'Infubinol', 'Ceftamin']

# Create empty list to fill with tumor vol data (for plotting)
tumor_vol = []

# Calculate the IQR and quantitatively determine if there are any potential outliers. 
quartiles = best_time_df['Tumor Volume (mm3)'].quantile([.25,.5,.75])
lowerq = quartiles[0.25]
upperq = quartiles[0.75]
iqr = upperq-lowerq

lower_bound = lowerq - (1.5*iqr)
upper_bound = upperq + (1.5*iqr)

print(f'The lower bound of the IQR is {lower_bound}, while the upper bound of the IQR is {upper_bound}.')
outliers_bool = (best_time_df['Tumor Volume (mm3)'] > upper_bound) | (best_time_df['Tumor Volume (mm3)'] < lower_bound)
outliers = best_time_df[outliers_bool]
print(f'There are {len(outliers)} outliers.')
outliers
# Locate the rows which contain mice on each drug and get the tumor volumes
    
    
# add subset 
    
    
    # Determine outliers using upper and lower bounds
# Out:
# The lower bound of the IQR is 17.109230961249963, while the upper bound of the IQR is 93.82025999125004.
# There are 0 outliers.
# Empty DataFrame
# Columns: [Mouse ID, Best Timepoint, Tumor Volume (mm3), Metastatic Sites, Drug Regimen, Sex, Age_months, Weight (g)]
# Index: []

# %%
# Generate a box plot of the final tumor volume of each mouse across four regimens of interest
# Run Cell Twice to Resize
fig, (all_treatments, Capomulin, Ramicane, Infubinol, Ceftamin) = plt.subplots(5, sharex=True)
fig.suptitle("Final Tumor Volume by Drug", fontsize=16, fontweight="bold")
all_treatments.boxplot(best_time_df['Tumor Volume (mm3)'])
all_treatments.set_xlabel('All Treatments')
all_treatments.set_ylabel('Tumor Vol')
Capomulin.boxplot(best_time_df[best_time_df['Drug Regimen'] == 'Capomulin']['Tumor Volume (mm3)'])
Capomulin.set_xlabel('Capomulin')
Capomulin.set_ylabel('Tumor Vol')
Ramicane.boxplot(best_time_df[best_time_df['Drug Regimen'] == 'Ramicane']['Tumor Volume (mm3)'])
Ramicane.set_xlabel('Ramicane')
Ramicane.set_ylabel('Tumor Vol')
Infubinol.boxplot(best_time_df[best_time_df['Drug Regimen'] == 'Infubinol']['Tumor Volume (mm3)'])
Infubinol.set_xlabel('Infubinol')
Infubinol.set_ylabel('Tumor Vol')
Ceftamin.boxplot(best_time_df[best_time_df['Drug Regimen'] == 'Ceftamin']['Tumor Volume (mm3)'])
Ceftamin.set_xlabel('Ceftamin')
Ceftamin.set_ylabel('Tumor Vol')
plt.rcParams["figure.figsize"] = [16,8]
plt.show()

# %%
# Generate a line plot of time point versus tumor volume for a mouse treated with Capomulin
plt.style.use(['classic'])
timepoint_axis = study_meta['Timepoint'].unique()
capomulin_df = study_meta[study_meta['Drug Regimen'] == 'Capomulin']
plt.plot(timepoint_axis, capomulin_df[capomulin_df['Mouse ID'] == 'b128']['Tumor Volume (mm3)'], 'r--d', label = 'Mouse b128')
plt.xlabel('Timepoint')
plt.ylabel('Tumor Volume (mm3)')
plt.title('Tumor Volume across Capomulin Study for Mouse b128')
# Out:
# Text(0.5, 1.0, 'Tumor Volume across Capomulin Study for Mouse b128')

# %%
# Generate a scatter plot of mouse weight versus average tumor volume for the Capomulin regimen
avg_tumor_vol = capomulin_df.groupby('Mouse ID')['Tumor Volume (mm3)'].mean()
best_time_capomulin = best_time_df[best_time_df['Drug Regimen'] == 'Capomulin']
capomulin_best_df = pd.merge(best_time_capomulin, avg_tumor_vol, how = 'left', on = 'Mouse ID')
capomulin_best_df = capomulin_best_df.rename(columns = {'Tumor Volume (mm3)_x': 'Final Tumor Vol', 
                                                        'Tumor Volume (mm3)_y': 'Mean Tumor Vol'})
plt.scatter(capomulin_best_df['Weight (g)'], capomulin_best_df['Mean Tumor Vol'])
plt.xlabel('Weight (g)')
plt.ylabel('Mean Tumor Volume')
plt.title('Average Tumor Volume vs Weight by Mouse, Capomulin Study')
# Out:
# Text(0.5, 1.0, 'Average Tumor Volume vs Weight by Mouse, Capomulin Study')

# %%
# Calculate the correlation coefficient and linear regression model 
print("The correlation coefficient between alcohol and color intensity is",
      f"{round(st.pearsonr(capomulin_best_df['Weight (g)'],capomulin_best_df['Mean Tumor Vol'])[0],2)}")
# Out:
# The correlation coefficient between alcohol and color intensity is 0.84

# %%
# for mouse weight and average tumor volume for the Capomulin regimen
x_values = capomulin_best_df['Weight (g)']
y_values = capomulin_best_df['Mean Tumor Vol']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(20, 34),fontsize=15,color="red")
plt.xlabel('Weight (g)')
plt.ylabel('Mean Tumor Vol')
plt.title('Weight(g) v. Average Tumor Volume(mm3), Linear Regression')
# Out:
# Text(0.5, 1.0, 'Weight(g) v. Average Tumor Volume(mm3), Linear Regression')
